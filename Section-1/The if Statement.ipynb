# %%
import numpy as np
from numpy.random import randn

# %%
randn()
# Out:
# -0.2266121653847918

# %%
answer = None
x = randn()
if x > 1:
    answer = "Greater than 1"
elif x >= -1:
    answer = "Between -1 and 1"
else:
    answer = "Less than -1"
print(x)
print(answer)
# Out:
# -0.13877132100461126
# Between -1 and 1

# %%
randn
# Out:
# <module 'numpy.random' from '/opt/anaconda3/lib/python3.13/site-packages/numpy/random/__init__.py'>
