# %%
A = 10

# %%
B = 5

# %%
C = A + B

# %%
D = A / B

# %%
#Printing

# %%
print(C)
# Out:
# 15

# %%
print(D)
# Out:
# 2.0

# %%
print(C)
print(D)
# Out:
# 15
# 2.0

# %%
import math

# %%
math.sqrt(A)
# Out:
# 3.1622776601683795

# %%
math.sqrt(B)
# Out:
# 2.23606797749979

# %%
round(A)
# Out:
# 10

# %%
round(math.sqrt(A))
# Out:
# 3

# %%
greeting = "Hello"

# %%
name = "bob"

# %%
message =  greeting + " " +  name

# %%
print(message)
# Out:
# Hello bob
