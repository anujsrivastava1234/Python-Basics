# %%
print("Hello, World")
# Out:
# Hello, World

# %%
#integer
x = 2

# %%
print(x)
# Out:
# 2

# %%
type(x)
# Out:
# int

# %% [markdown]
# ---

# %%
#float / double
x = 2.5

# %%
print(x)
# Out:
# 2.5

# %%
type(x)
# Out:
# float

# %% [markdown]
# ---

# %%
a = "hello"
b = 'hello'

# %%
print(a)
# Out:
# hello

# %%
type(a)
# Out:
# str

# %%
print(b)
# Out:
# hello

# %%
a
# Out:
# 'hello'

# %%
b
# Out:
# 'hello'

# %%
---
# Out:
#   Cell In[18], line 1
#     ---
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---

# %%
q1 = True

# %%
print(q1)
# Out:
# True

# %%
type(q1)
# Out:
# bool
