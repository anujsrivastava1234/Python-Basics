# %%
4 < 5
# Out:
# True

# %%
10 > 1000
# Out:
# False

# %%
4 == 5
# Out:
# False

# %%
# == 
# != <>

# %%
result = 5 < 4

# %%
print(result)
# Out:
# False

# %%
result
# Out:
# False

# %%
result2 = not(5 < 1)

# %%
result2
# Out:
# True

# %%
result or result2
# Out:
# True

# %%
result and result2
# Out:
# False
