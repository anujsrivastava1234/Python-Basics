# %%
import numpy as np

# %%
l = [1, 2, 3, 4, 5]

# %%
a = np.array(l)

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = np.array([12, 34, 44.5,'a'])

# %%
b
# Out:
# array(['12', '34', '44.5', 'a'], dtype='<U32')

# %%
print(b)
# Out:
# ['12' '34' '44.5' 'a']

# %%
l.pop()
# Out:
# 5

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
a.mean()
# Out:
# np.float64(3.0)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l[0:2:1]
# Out:
# [1, 2]

# %%
l[::2]
# Out:
# [1, 3]

# %%
a[2:]
# Out:
# array([3, 4, 5])

# %%
a[2:4]
# Out:
# array([3, 4])

# %%
b = a[::2]

# %%
b
# Out:
# array([1, 3, 5])

# %%
b[:1] = 111

# %%
b
# Out:
# array([111,   3,   5])

# %%
b[:]
# Out:
# array([111,   3,   5])

# %%
b[:] = 111

# %%
b
# Out:
# array([111, 111, 111])

# %%
a
# Out:
# array([111,   2, 111,   4, 111])

# %% [markdown]
# ---

# %%
#Copy

# %%
c = a.copy()

# %%
c
# Out:
# array([111,   2, 111,   4, 111])

# %%
c[0] = 0

# %%
c
# Out:
# array([  0,   2, 111,   4, 111])

# %%
c[:] = 5

# %%
c[::2] = 11

# %%
c
# Out:
# array([11, 11, 11,  5, 11])

# %%
c[::1] = 5

# %%
c
# Out:
# array([11, 11,  5,  5,  5])

# %%
a
# Out:
# array([111,   2, 111,   4, 111])
